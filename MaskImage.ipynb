# %%
# # Masking

# import cv2
# import os
# import numpy as np


# video_path = "dumbvideo.mp4"
# output_dir = "masking_out_directory"

# if not os.path.exists(video_path):
#     print(f"{video_path}: File not found.")

# # Create output directory if it doesn't exist
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Open the video file
# cap = cv2.VideoCapture(video_path)
# fps = cap.get(cv2.CAP_PROP_FPS)
    
# if fps <= 0:
#     print(f"Error: Could not retrieve FPS from {video_path}")


# scenes = []
# index = 0
# success, frame = cap.read()
# count = 0

# while success:
#     # Capture frame every second (approximately)
#     if count % int(fps) == 0:
#         img_file = os.path.join(output_dir, f"scene_{index}.jpg")
        
#         # Save the frame as an image file
#         cv2.imwrite(img_file, frame)
        
#         # Append scene info to the list
#         scenes.append({
#             "index": index,
#             "img_file": img_file
#         })
        
#         index += 1
    
#     success, frame = cap.read()
#     count += 1

# cap.release()



# # Replace 'your_image_path.jpg' with the actual path to your image file
# image_path = "imagemask3.png"

# # Load the image from the specified path
# frame = cv2.imread(image_path)

# if frame is None:
#     print("Failed to load image. Please check the file path.")
# else:
#     # Step 1: HSV thresholding
#     hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#     lower_hsv = np.array([0, 0, 120])
#     upper_hsv = np.array([180, 38, 255])
#     mask = cv2.inRange(hsv, lower_hsv, upper_hsv)
#     result = cv2.bitwise_and(frame, frame, mask=mask)
#     _, g, _ = cv2.split(result)
#     filtered = g.copy()

#     # Step 2: Binary thresholding
#     ret, binary_mask = cv2.threshold(filtered, 10, 255, cv2.THRESH_BINARY)

#     # Step 3: Masking input image with the binary mask (Invert logic for foreground)
#     bg_removed = frame.copy()
#     bg_removed[binary_mask != 0] = [255, 255, 255]  # Set background to white, keep foreground

#     # Save the background-removed image
#     output_path = "background_removed.jpg"
#     cv2.imwrite(output_path, bg_removed)
#     print(f"Background-removed image saved to: {output_path}")

# %%
# import cv2
# import os
# import numpy as np

# # Input and output paths
# video_path = "dumbvideo.mp4"
# output_dir = "masking_out_directory"

# # Ensure video file exists
# if not os.path.isfile(video_path):
#     print(f"Error: {video_path} not found.")
#     exit()

# # Create output directory if it doesn't exist
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Open the video file
# cap = cv2.VideoCapture(video_path)
# fps = cap.get(cv2.CAP_PROP_FPS)

# # Validate FPS
# if fps <= 0:
#     print(f"Error: Could not retrieve FPS from {video_path}")
#     cap.release()
#     exit()

# frame_interval = int(fps)  # Extract a frame every second
# index = 0
# count = 0
# success, frame = cap.read()

# while success:
#     if count % frame_interval == 0:
#         img_file = os.path.join(output_dir, f"scene_{index}.png")
        
#         # Apply masking to the extracted frame
#         hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
#         lower_hsv = np.array([0, 0, 120])
#         upper_hsv = np.array([180, 38, 255])
#         mask = cv2.inRange(hsv, lower_hsv, upper_hsv)
#         result = cv2.bitwise_and(frame, frame, mask=mask)
#         _, g, _ = cv2.split(result)
#         filtered = g.copy()

#         # Apply binary threshold
#         _, binary_mask = cv2.threshold(filtered, 10, 255, cv2.THRESH_BINARY)

#         # Apply background removal
#         bg_removed = frame.copy()
#         bg_removed[binary_mask != 0] = [255, 255, 255]  # Set background to white
        
#         # Save the processed image
#         cv2.imwrite(img_file, bg_removed)
#         print(f"Saved masked frame: {img_file}")
        
#         index += 1
    
#     success, frame = cap.read()
#     count += 1

# cap.release()
# print("Processing complete.")

# %%
import cv2
import os
import numpy as np

# Input and output paths
video_path = "Masking_Image/test9_cs412-21s.mp4"
output_dir = "masking_out_directory"

# Ensure video file exists
if not os.path.isfile(video_path):
    print(f"Error: {video_path} not found.")
    exit()

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Open the video file
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)

# Validate FPS
if fps <= 0:
    print(f"Error: Could not retrieve FPS from {video_path}")
    cap.release()
    exit()

frame_interval = int(fps)  # Extract a frame every second
index = 0
count = 0
success, frame = cap.read()

while success:
    if count % frame_interval == 0:
        img_file = os.path.join(output_dir, f"scene_{index}.png")
        
        # Apply masking to the extracted frame
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
        lower_hsv = np.array([0, 0, 120])
        upper_hsv = np.array([180, 38, 255])
        mask = cv2.inRange(hsv, lower_hsv, upper_hsv)
        result = cv2.bitwise_and(frame, frame, mask=mask)
        _, g, _ = cv2.split(result)
        filtered = g.copy()

        # Apply binary threshold
        _, binary_mask = cv2.threshold(filtered, 10, 255, cv2.THRESH_BINARY)

        # Apply background removal
        bg_removed = frame.copy()
        bg_removed[binary_mask != 0] = [255, 255, 255]  # Set background to white
        
        # Save the processed image
        cv2.imwrite(img_file, bg_removed)
        print(f"Saved masked frame: {img_file}")
        
        index += 1
    
    success, frame = cap.read()
    count += 1

cap.release()
print("Processing complete.")
# Out:
# Saved masked frame: masking_out_directory/scene_0.png
# Saved masked frame: masking_out_directory/scene_1.png
# Saved masked frame: masking_out_directory/scene_2.png
# Saved masked frame: masking_out_directory/scene_3.png
# Saved masked frame: masking_out_directory/scene_4.png
# Saved masked frame: masking_out_directory/scene_5.png
# Saved masked frame: masking_out_directory/scene_6.png
# Saved masked frame: masking_out_directory/scene_7.png
# Saved masked frame: masking_out_directory/scene_8.png
# Saved masked frame: masking_out_directory/scene_9.png
# Saved masked frame: masking_out_directory/scene_10.png
# Saved masked frame: masking_out_directory/scene_11.png
# Saved masked frame: masking_out_directory/scene_12.png
# Saved masked frame: masking_out_directory/scene_13.png
# Saved masked frame: masking_out_directory/scene_14.png
# Saved masked frame: masking_out_directory/scene_15.png
# Saved masked frame: masking_out_directory/scene_16.png
# Saved masked frame: masking_out_directory/scene_17.png
# Saved masked frame: masking_out_directory/scene_18.png
# Saved masked frame: masking_out_directory/scene_19.png
# Saved masked frame: masking_out_directory/scene_20.png
# Processing complete.

# %%
# Contour Masking
import cv2
import os
import numpy as np

# Input and output paths
video_path = "data/videos/ScreenRecording.mov"
output_dir = "masking_out_directory2"

# Ensure video file exists
if not os.path.isfile(video_path):
    print(f"Error: {video_path} not found.")
    exit()

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Open the video file
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)

# Validate FPS
if fps <= 0:
    print(f"Error: Could not retrieve FPS from {video_path}")
    cap.release()
    exit()

frame_interval = int(fps)  # Extract a frame every second
index = 0
count = 0
success, frame = cap.read()

previous_canvas = None  # Store the previous frame's contours

while success:
    if count % frame_interval == 0:
        img_file = os.path.join(output_dir, f"scene_{index}.jpg")

        # Convert frame to grayscale
        image_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Convert grayscale to binary (black and white)
        _, image_edges = cv2.threshold(image_gray, 100, 255, cv2.THRESH_BINARY)

        # Create white canvas, mask, and background
        canvas = np.full(frame.shape, 255, np.uint8)
        mask = np.full(frame.shape, 255, np.uint8)
        new_background = np.full(frame.shape, 255, np.uint8)

        # Find contours
        contours_draw, _ = cv2.findContours(image_edges, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
        contours_mask, _ = cv2.findContours(image_edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        # Draw all contours on the canvas
        for contour in range(len(contours_draw)):
            cv2.drawContours(canvas, contours_draw, contour, (0, 0, 0), 3)

        # Create mask and background
        for contour in range(len(contours_mask)):
            if contour != 1:
                cv2.fillConvexPoly(mask, contours_mask[contour], (0, 0, 0))
                cv2.fillConvexPoly(new_background, contours_mask[contour], (0, 255, 0))  # Green background

        # Apply the mask to remove the background
        output_frame = cv2.bitwise_and(frame, new_background)

        # Save the processed images
        cv2.imwrite(img_file, output_frame)
        contours_file = os.path.join(output_dir, f"contours_{index}.png")
        mask_file = os.path.join(output_dir, f"mask_{index}.png")
        background_file = os.path.join(output_dir, f"background_{index}.png")

        cv2.imwrite(contours_file, canvas)
        cv2.imwrite(mask_file, mask)
        cv2.imwrite(background_file, new_background)

        print(f"Saved masked frame: {img_file}")

        # Compute difference with the previous contour frame and save
        if previous_canvas is not None:
            diff = cv2.absdiff(previous_canvas, canvas)  # Subtract adjacent frames
            diff_file = os.path.join(output_dir, f"contour_diff_{index-1}_{index}.png")
            cv2.imwrite(diff_file, diff)
            print(f"Saved difference frame: {diff_file}")

        # Update previous canvas
        previous_canvas = canvas.copy()

        index += 1

    success, frame = cap.read()
    count += 1

cap.release()
print("Processing complete.")
# Out:
# Saved masked frame: masking_out_directory2/scene_0.jpg
# Saved masked frame: masking_out_directory2/scene_1.jpg
# Saved difference frame: masking_out_directory2/contour_diff_0_1.png
# Saved masked frame: masking_out_directory2/scene_2.jpg
# Saved difference frame: masking_out_directory2/contour_diff_1_2.png
# Saved masked frame: masking_out_directory2/scene_3.jpg
# Saved difference frame: masking_out_directory2/contour_diff_2_3.png
# Saved masked frame: masking_out_directory2/scene_4.jpg
# Saved difference frame: masking_out_directory2/contour_diff_3_4.png
# Saved masked frame: masking_out_directory2/scene_5.jpg
# Saved difference frame: masking_out_directory2/contour_diff_4_5.png
# Saved masked frame: masking_out_directory2/scene_6.jpg
# Saved difference frame: masking_out_directory2/contour_diff_5_6.png
# Saved masked frame: masking_out_directory2/scene_7.jpg
# Saved difference frame: masking_out_directory2/contour_diff_6_7.png
# Saved masked frame: masking_out_directory2/scene_8.jpg
# Saved difference frame: masking_out_directory2/contour_diff_7_8.png
# Saved masked frame: masking_out_directory2/scene_9.jpg
# Saved difference frame: masking_out_directory2/contour_diff_8_9.png
# Saved masked frame: masking_out_directory2/scene_10.jpg
# Saved difference frame: masking_out_directory2/contour_diff_9_10.png
# Saved masked frame: masking_out_directory2/scene_11.jpg
# Saved difference frame: masking_out_directory2/contour_diff_10_11.png
# Saved masked frame: masking_out_directory2/scene_12.jpg
# Saved difference frame: masking_out_directory2/contour_diff_11_12.png
# Saved masked frame: masking_out_directory2/scene_13.jpg
# Saved difference frame: masking_out_directory2/contour_diff_12_13.png
# Saved masked frame: masking_out_directory2/scene_14.jpg
# Saved difference frame: masking_out_directory2/contour_diff_13_14.png
# Saved masked frame: masking_out_directory2/scene_15.jpg
# Saved difference frame: masking_out_directory2/contour_diff_14_15.png
# Saved masked frame: masking_out_directory2/scene_16.jpg
# Saved difference frame: masking_out_directory2/contour_diff_15_16.png
# Saved masked frame: masking_out_directory2/scene_17.jpg
# Saved difference frame: masking_out_directory2/contour_diff_16_17.png
# Saved masked frame: masking_out_directory2/scene_18.jpg
# Saved difference frame: masking_out_directory2/contour_diff_17_18.png
# Saved masked frame: masking_out_directory2/scene_19.jpg
# Saved difference frame: masking_out_directory2/contour_diff_18_19.png
# Saved masked frame: masking_out_directory2/scene_20.jpg
# Saved difference frame: masking_out_directory2/contour_diff_19_20.png
# Saved masked frame: masking_out_directory2/scene_21.jpg
# Saved difference frame: masking_out_directory2/contour_diff_20_21.png
# Saved masked frame: masking_out_directory2/scene_22.jpg
# Saved difference frame: masking_out_directory2/contour_diff_21_22.png
# Saved masked frame: masking_out_directory2/scene_23.jpg
# Saved difference frame: masking_out_directory2/contour_diff_22_23.png
# Saved masked frame: masking_out_directory2/scene_24.jpg
# Saved difference frame: masking_out_directory2/contour_diff_23_24.png
# Saved masked frame: masking_out_directory2/scene_25.jpg
# Saved difference frame: masking_out_directory2/contour_diff_24_25.png
# Processing complete.
